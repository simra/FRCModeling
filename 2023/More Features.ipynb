# %% [markdown]
# ## 2023 TBA Predictions

# %% [markdown]
# Load the training data into a pandas data frame.

# %%
from __future__ import print_function
import pickle
#import time
import sys
sys.path.append('..')
import swagger_client as v3client
from swagger_client.rest import ApiException

filename = 'matches_2023.pkl'
matches = []
with open(filename, 'rb') as f:
    matches = pickle.load(f)

print(f'{len(matches["matches"])} events')
# Out:
# 181 events

# %% [markdown]
# Preview a match object

# %%
non_empty = [k for k in matches['matches'].keys() if len(matches['matches'][k])>0]
data = [m for k in matches['matches'] for m in matches['matches'][k]]
data = [m for m in data if m.winning_alliance!='']
print(f'{len(data)} matches')
data[0]
#red = [x for m in data for x in m.alliances.red.team_keys]
#blue = [x for m in data for x in m.alliances.blue.team_keys]
#from collections import Counter
#Counter(red+blue)
# Out:
# 2365 matches
# {'actual_time': 1677970247,
#  'alliances': {'blue': {'dq_team_keys': [],
#                         'score': 108,
#                         'surrogate_team_keys': [],
#                         'team_keys': ['frc4522', 'frc6055', 'frc3937']},
#                'red': {'dq_team_keys': [],
#                        'score': 131,
#                        'surrogate_team_keys': [],
#                        'team_keys': ['frc4766', 'frc16', 'frc6586']}},
#  'comp_level': 'f',
#  'event_key': '2023arli',
#  'key': '2023arli_f1m1',
#  'match_number': 1,
#  'post_result_time': 1677970426,
#  'predicted_time': 1677970128,
#  'score_breakdown': {'blue': {'activationBonusAchieved': False,
#                               'adjustPoints': 0,
#                               'autoBridgeState': 'Level',
#                               'autoChargeStationPoints': 12,
#                               'autoChargeStationRobot1': 'None',
#                               'autoChargeStationRobot2': 'None',
#                               'autoChargeStationRobot3': 'Docked',
#                               'autoCommunity': {'B': ['None',
#                                                       'None',
#                                                       'None',
#                                                       'None',
#                                                       'None',
#                                                       'None',
#                                                       'None',
#                                                       'None',
#                                                       'None'],
#                                                 'M': ['None',
#                                                       'None',
#                                                       'None',
#                                                       'Cone',
#                                                       'None',
#                                                       'None',
#                                                       'None',
#                                                       'None',
#                                                       'None'],
#                                                 'T': ['None',
#                                                       'None',
#                                                       'None',
#                                                       'None',
#                                                       'None',
#                                                       'None',
#                                                       'None',
#                                                       'None',
#                                                       'None']},
#                               'autoDocked': True,
#                               'autoGamePieceCount': 1,
#                               'autoGamePiecePoints': 4,
#                               'autoMobilityPoints': 3,
#                               'autoPoints': 19,
#                               'coopGamePieceCount': 5,
#                               'coopertitionCriteriaMet': False,
#                               'endGameBridgeState': 'Level',
#                               'endGameChargeStationPoints': 30,
#                               'endGameChargeStationRobot1': 'Docked',
#                               'endGameChargeStationRobot2': 'Docked',
#                               'endGameChargeStationRobot3': 'Docked',
#                               'endGameParkPoints': 0,
#                               'foulCount': 1,
#                               'foulPoints': 0,
#                               'linkPoints': 10,
#                               'links': [{'nodes': [0, 1, 2], 'row': 'Mid'},
#                                         {'nodes': [0, 1, 2], 'row': 'Top'}],
#                               'mobilityRobot1': 'No',
#                               'mobilityRobot2': 'No',
#                               'mobilityRobot3': 'Yes',
#                               'rp': 0,
#                               'sustainabilityBonusAchieved': False,
#                               'techFoulCount': 0,
#                               'teleopCommunity': {'B': ['Cube',
#                                                         'None',
#                                                         'None',
#                                                         'Cube',
#                                                         'None',
#                                                         'None',
#                                                         'None',
#                                                         'None',
#                                                         'None'],
#                                                   'M': ['Cone',
#                                                         'Cube',
#                                                         'Cone',
#                                                         'Cone',
#                                                         'Cube',
#                                                         'None',
#                                                         'None',
#                                                         'Cube',
#                                                         'None'],
#                                                   'T': ['Cone',
#                                                         'Cube',
#                                                         'Cone',
#                                                         'Cone',
#                                                         'Cube',
#                                                         'None',
#                                                         'None',
#                                                         'Cube',
#                                                         'None']},
#                               'teleopGamePieceCount': 14,
#                               'teleopGamePiecePoints': 49,
#                               'teleopPoints': 79,
#                               'totalChargeStationPoints': 42,
#                               'totalPoints': 108},
#                      'red': {'activationBonusAchieved': False,
#                              'adjustPoints': 0,
#                              'autoBridgeState': 'Level',
#                              'autoChargeStationPoints': 12,
#                              'autoChargeStationRobot1': 'None',
#                              'autoChargeStationRobot2': 'Docked',
#                              'autoChargeStationRobot3': 'None',
#                              'autoCommunity': {'B': ['None',
#                                                      'None',
#                                                      'None',
#                                                      'None',
#                                                      'None',
#                                                      'None',
#                                                      'None',
#                                                      'None',
#                                                      'None'],
#                                                'M': ['None',
#                                                      'None',
#                                                      'None',
#                                                      'None',
#                                                      'None',
#                                                      'None',
#                                                      'None',
#                                                      'None',
#                                                      'None'],
#                                                'T': ['Cone',
#                                                      'None',
#                                                      'None',
#                                                      'None',
#                                                      'Cube',
#                                                      'None',
#                                                      'None',
#                                                      'Cube',
#                                                      'None']},
#                              'autoDocked': True,
#                              'autoGamePieceCount': 3,
#                              'autoGamePiecePoints': 18,
#                              'autoMobilityPoints': 6,
#                              'autoPoints': 36,
#                              'coopGamePieceCount': 1,
#                              'coopertitionCriteriaMet': False,
#                              'endGameBridgeState': 'Level',
#                              'endGameChargeStationPoints': 30,
#                              'endGameChargeStationRobot1': 'Docked',
#                              'endGameChargeStationRobot2': 'Docked',
#                              'endGameChargeStationRobot3': 'Docked',
#                              'endGameParkPoints': 0,
#                              'foulCount': 0,
#                              'foulPoints': 5,
#                              'linkPoints': 20,
#                              'links': [{'nodes': [0, 1, 2], 'row': 'Bottom'},
#                                        {'nodes': [6, 7, 8], 'row': 'Mid'},
#                                        {'nodes': [0, 1, 2], 'row': 'Top'},
#                                        {'nodes': [6, 7, 8], 'row': 'Top'}],
#                              'mobilityRobot1': 'Yes',
#                              'mobilityRobot2': 'Yes',
#                              'mobilityRobot3': 'No',
#                              'rp': 0,
#                              'sustainabilityBonusAchieved': False,
#                              'techFoulCount': 0,
#                              'teleopCommunity': {'B': ['Cube',
#                                                        'Cube',
#                                                        'Cube',
#                                                        'None',
#                                                        'None',
#                                                        'None',
#                                                        'Cube',
#                                                        'None',
#                                                        'None'],
#                                                  'M': ['None',
#                                                        'Cube',
#                                                        'None',
#                                                        'None',
#                                                        'None',
#                                                        'None',
#                                                        'Cone',
#                                                        'Cube',
#                                                        'Cone'],
#                                                  'T': ['Cone',
#                                                        'Cube',
#                                                        'Cone',
#                                                        'None',
#                                                        'Cube',
#                                                        'None',
#                                                        'Cone',
#                                                        'Cube',
#                                                        'Cone']},
#                              'teleopGamePieceCount': 15,
#                              'teleopGamePiecePoints': 40,
#                              'teleopPoints': 70,
#                              'totalChargeStationPoints': 42,
#                              'totalPoints': 131}},
#  'set_number': 1,
#  'time': 1677966780,
#  'videos': [{'key': '_aIt9EholEA', 'type': 'youtube'}],
#  'winning_alliance': 'red'}

# %% [markdown]
# List the fields in a single alliance match

# %%
list(data[0].score_breakdown['blue'].keys())
# Out:
# ['activationBonusAchieved',
#  'adjustPoints',
#  'autoBridgeState',
#  'autoChargeStationPoints',
#  'autoChargeStationRobot1',
#  'autoChargeStationRobot2',
#  'autoChargeStationRobot3',
#  'autoCommunity',
#  'autoDocked',
#  'autoGamePieceCount',
#  'autoGamePiecePoints',
#  'autoMobilityPoints',
#  'autoPoints',
#  'coopGamePieceCount',
#  'coopertitionCriteriaMet',
#  'endGameBridgeState',
#  'endGameChargeStationPoints',
#  'endGameChargeStationRobot1',
#  'endGameChargeStationRobot2',
#  'endGameChargeStationRobot3',
#  'endGameParkPoints',
#  'foulCount',
#  'foulPoints',
#  'linkPoints',
#  'links',
#  'mobilityRobot1',
#  'mobilityRobot2',
#  'mobilityRobot3',
#  'rp',
#  'sustainabilityBonusAchieved',
#  'techFoulCount',
#  'teleopCommunity',
#  'teleopGamePieceCount',
#  'teleopGamePiecePoints',
#  'teleopPoints',
#  'totalChargeStationPoints',
#  'totalPoints']

# %% [markdown]
# This cell goes into more detail about what's in each field.

# %%
#data[0].score_breakdown['blue'].keys()

#endgameFields = Counter()
#taxiFields = Counter()
#for d in data:
#   endgameFields[d.score_breakdown['blue']['endgameRobot1']]+=1
#   endgameFields[d.score_breakdown['blue']['endgameRobot2']]+=1
#   endgameFields[d.score_breakdown['blue']['endgameRobot3']]+=1
#   taxiFields[d.score_breakdown['blue']['taxiRobot1']]+=1
#   taxiFields[d.score_breakdown['blue']['taxiRobot2']]+=1
#   taxiFields[d.score_breakdown['blue']['taxiRobot3']]+=1
#print(endgameFields)
#print(taxiFields)
stats = set()
for d in data:
    for k in d.score_breakdown['blue']:
        v = d.score_breakdown['blue'][k]
        t = type(v)
        if t is int:
            stats.add(k)
        elif t is bool or t is str:
            stats.add(f'{k}.{str(v)}')
        elif t is dict:
            for k2 in v:
                #if type(v[k2]) is list:
                #    for v2 in v[k2]:
                #        stats.add(f'{k}.{k2}.[{v2}]')
                #else:
                #stats.add(f'{k}.{k2}.{str(type(v[k2]))}')
                stats.add(f'{k}.{k2}.{type(v[k2])}')
        elif t is list:
            stats.add(f'{k}.{str(t)}')
            #for v2 in v:
            #    stats.add(f'{k}.[{str(v2)}]')
                
for k in sorted(stats):
    print(k)
# Out:
# activationBonusAchieved.False
# activationBonusAchieved.True
# adjustPoints
# autoBridgeState.Level
# autoBridgeState.NotLevel
# autoChargeStationPoints
# autoChargeStationRobot1.Docked
# autoChargeStationRobot1.None
# autoChargeStationRobot2.Docked
# autoChargeStationRobot2.None
# autoChargeStationRobot3.Docked
# autoChargeStationRobot3.None
# autoCommunity.B.<class 'list'>
# autoCommunity.M.<class 'list'>
# autoCommunity.T.<class 'list'>
# autoDocked.False
# autoDocked.True
# autoGamePieceCount
# autoGamePiecePoints
# autoMobilityPoints
# autoPoints
# coopGamePieceCount
# coopertitionCriteriaMet.False
# coopertitionCriteriaMet.True
# endGameBridgeState.Level
# endGameBridgeState.NotLevel
# endGameChargeStationPoints
# endGameChargeStationRobot1.Docked
# endGameChargeStationRobot1.None
# endGameChargeStationRobot1.Park
# endGameChargeStationRobot2.Docked
# endGameChargeStationRobot2.None
# endGameChargeStationRobot2.Park
# endGameChargeStationRobot3.Docked
# endGameChargeStationRobot3.None
# endGameChargeStationRobot3.Park
# endGameParkPoints
# foulCount
# foulPoints
# linkPoints
# links.<class 'list'>
# mobilityRobot1.No
# mobilityRobot1.Yes
# mobilityRobot2.No
# mobilityRobot2.Yes
# mobilityRobot3.No
# mobilityRobot3.Yes
# rp
# sustainabilityBonusAchieved.False
# sustainabilityBonusAchieved.True
# techFoulCount
# teleopCommunity.B.<class 'list'>
# teleopCommunity.M.<class 'list'>
# teleopCommunity.T.<class 'list'>
# teleopGamePieceCount
# teleopGamePiecePoints
# teleopPoints
# totalChargeStationPoints
# totalPoints

# %%
from collections import Counter
Counter([x.comp_level for x in data])
# Out:
# Counter({'f': 66, 'qm': 1923, 'sf': 376})

# %% [markdown]
# As you can see there is a lot of information here.  We want to collect all of this together so that at the end of the regionals we have score statistics for every team.  We'll sum up all the integer and boolean values and average them over the team's matches.  Grid scores and other dictionary fields will get special treatment.

# %%
qualifiers = [x for x in data if x.comp_level=='qm' and x.score_breakdown is not None]

# %%
# This will store all the team statistics
teamAggregates = {}

def addMatch(team, m):    
    # initialize an empty record for the team if one doesn't already exist.        
    if team not in teamAggregates:       
        teamAggregates[team]= {
            'totalMatches':0, 
            'winCount': 0
        }
        for k in m.score_breakdown['blue'].keys():
            val = m.score_breakdown['blue'][k]
            if type(val) is int or type(val) is bool:
                teamAggregates[team][f'{k}Total'] = 0
            elif type(val) is dict:
                for f in ['B','M','T']:
                    for e in ['Cone','Cube']:
                        for i in range(9):
                            teamAggregates[team][f'{k}.{f}.{e}.{i}.Total'] = 0
            elif type(val) is list:
                # TODO: links
                pass
            
        for r in [1,2,3]:
            for v in ['Yes', 'No']:
                teamAggregates[team][f'mobilityRobot{r}{v}Total'] = 0
            for e in ['None', 'Docked', 'Park']:
                teamAggregates[team][f'endGameChargeStationRobot{r}{e}Total'] = 0 
                if e=='Park':
                    continue # parked doesn't apply to autonomous
                teamAggregates[team][f'autoChargeStationRobot{r}{e}Total'] = 0 
        for e in ['Level', 'NotLevel']:
            teamAggregates[team][f'endGameBridgeState{e}Total'] = 0
            teamAggregates[team][f'autoBridgeState{e}Total'] = 0
            
                
        
    # update the stats for this team
    alliance = 'blue' if team in m.alliances.blue.team_keys else 'red'
    points = m.score_breakdown[alliance]
    #print(points)
    summary = teamAggregates[team]
    # update all of the fields.
    summary['totalMatches']+=1    
    
    # TODO: figure out if we are robot 1, 2, or 3.
    for r in [1, 2, 3]:        
        summary[f'mobilityRobot{r}{points[f"mobilityRobot{r}"]}Total'] += 1
        summary[f'endGameChargeStationRobot{r}{points[f"endGameChargeStationRobot{r}"]}Total'] += 1
        summary[f'autoChargeStationRobot{r}{points[f"autoChargeStationRobot{r}"]}Total'] += 1
    summary[f'endGameBridgeState{points["endGameBridgeState"]}Total'] += 1
    summary[f'autoBridgeState{points["autoBridgeState"]}Total'] += 1
    
    for k in ['B','M','T']:
        for i in range(9):
            for f in ['teleop','auto']:
                v = points[f'{f}Community'][k][i]
                if v == 'None':
                    continue
                teamAggregates[team][f'{f}Community.{k}.{v}.{i}.Total'] += 1
    
    for k in points.keys():
        if type(points[k]) is int:
            summary[f'{k}Total'] += points[k]
        elif type(points[k]) is bool:
            summary[f'{k}Total'] += int(points[k])

    summary['winCount'] += int(m.winning_alliance==alliance)

# Currently just using Week0 events.
for m in qualifiers:
    # only aggregate statistics for regional matches- skip the districts or we're cheating.
    #if m.event_key=='2020pncmp':
    #    continue
    for t in m.alliances.red.team_keys:
        addMatch(t,m)
    for t in m.alliances.blue.team_keys:
        addMatch(t,m)
        
# normalize the aggregates
for t in teamAggregates:
    for k in teamAggregates[t]:
        if k=='totalMatches':
            continue
        teamAggregates[t][k]/=teamAggregates[t]['totalMatches']

with open('teamStats_2023.pkl','wb') as f:
    pickle.dump(teamAggregates,f)

# %%
teamAggregates['frc16']
# Out:
# {'totalMatches': 12,
#  'winCount': 0.75,
#  'activationBonusAchievedTotal': 0.75,
#  'adjustPointsTotal': 0.0,
#  'autoChargeStationPointsTotal': 11.0,
#  'autoCommunity.B.Cone.0.Total': 0.0,
#  'autoCommunity.B.Cone.1.Total': 0.0,
#  'autoCommunity.B.Cone.2.Total': 0.0,
#  'autoCommunity.B.Cone.3.Total': 0.0,
#  'autoCommunity.B.Cone.4.Total': 0.08333333333333333,
#  'autoCommunity.B.Cone.5.Total': 0.16666666666666666,
#  'autoCommunity.B.Cone.6.Total': 0.0,
#  'autoCommunity.B.Cone.7.Total': 0.0,
#  'autoCommunity.B.Cone.8.Total': 0.0,
#  'autoCommunity.B.Cube.0.Total': 0.0,
#  'autoCommunity.B.Cube.1.Total': 0.0,
#  'autoCommunity.B.Cube.2.Total': 0.0,
#  'autoCommunity.B.Cube.3.Total': 0.0,
#  'autoCommunity.B.Cube.4.Total': 0.08333333333333333,
#  'autoCommunity.B.Cube.5.Total': 0.0,
#  'autoCommunity.B.Cube.6.Total': 0.0,
#  'autoCommunity.B.Cube.7.Total': 0.0,
#  'autoCommunity.B.Cube.8.Total': 0.0,
#  'autoCommunity.M.Cone.0.Total': 0.0,
#  'autoCommunity.M.Cone.1.Total': 0.0,
#  'autoCommunity.M.Cone.2.Total': 0.0,
#  'autoCommunity.M.Cone.3.Total': 0.08333333333333333,
#  'autoCommunity.M.Cone.4.Total': 0.0,
#  'autoCommunity.M.Cone.5.Total': 0.0,
#  'autoCommunity.M.Cone.6.Total': 0.0,
#  'autoCommunity.M.Cone.7.Total': 0.0,
#  'autoCommunity.M.Cone.8.Total': 0.0,
#  'autoCommunity.M.Cube.0.Total': 0.0,
#  'autoCommunity.M.Cube.1.Total': 0.08333333333333333,
#  'autoCommunity.M.Cube.2.Total': 0.0,
#  'autoCommunity.M.Cube.3.Total': 0.0,
#  'autoCommunity.M.Cube.4.Total': 0.0,
#  'autoCommunity.M.Cube.5.Total': 0.0,
#  'autoCommunity.M.Cube.6.Total': 0.0,
#  'autoCommunity.M.Cube.7.Total': 0.0,
#  'autoCommunity.M.Cube.8.Total': 0.0,
#  'autoCommunity.T.Cone.0.Total': 0.75,
#  'autoCommunity.T.Cone.1.Total': 0.0,
#  'autoCommunity.T.Cone.2.Total': 0.0,
#  'autoCommunity.T.Cone.3.Total': 0.0,
#  'autoCommunity.T.Cone.4.Total': 0.0,
#  'autoCommunity.T.Cone.5.Total': 0.08333333333333333,
#  'autoCommunity.T.Cone.6.Total': 0.0,
#  'autoCommunity.T.Cone.7.Total': 0.0,
#  'autoCommunity.T.Cone.8.Total': 0.75,
#  'autoCommunity.T.Cube.0.Total': 0.0,
#  'autoCommunity.T.Cube.1.Total': 0.16666666666666666,
#  'autoCommunity.T.Cube.2.Total': 0.0,
#  'autoCommunity.T.Cube.3.Total': 0.0,
#  'autoCommunity.T.Cube.4.Total': 0.0,
#  'autoCommunity.T.Cube.5.Total': 0.0,
#  'autoCommunity.T.Cube.6.Total': 0.0,
#  'autoCommunity.T.Cube.7.Total': 0.25,
#  'autoCommunity.T.Cube.8.Total': 0.0,
#  'autoDockedTotal': 0.9166666666666666,
#  'autoGamePieceCountTotal': 2.5,
#  'autoGamePiecePointsTotal': 13.666666666666666,
#  'autoMobilityPointsTotal': 5.5,
#  'autoPointsTotal': 30.166666666666668,
#  'coopGamePieceCountTotal': 2.3333333333333335,
#  'coopertitionCriteriaMetTotal': 0.5,
#  'endGameChargeStationPointsTotal': 19.166666666666668,
#  'endGameParkPointsTotal': 1.1666666666666667,
#  'foulCountTotal': 0.8333333333333334,
#  'foulPointsTotal': 6.833333333333333,
#  'linkPointsTotal': 16.25,
#  'rpTotal': 2.5833333333333335,
#  'sustainabilityBonusAchievedTotal': 0.3333333333333333,
#  'techFoulCountTotal': 0.25,
#  'teleopCommunity.B.Cone.0.Total': 0.0,
#  'teleopCommunity.B.Cone.1.Total': 0.0,
#  'teleopCommunity.B.Cone.2.Total': 0.16666666666666666,
#  'teleopCommunity.B.Cone.3.Total': 0.25,
#  'teleopCommunity.B.Cone.4.Total': 0.16666666666666666,
#  'teleopCommunity.B.Cone.5.Total': 0.3333333333333333,
#  'teleopCommunity.B.Cone.6.Total': 0.16666666666666666,
#  'teleopCommunity.B.Cone.7.Total': 0.16666666666666666,
#  'teleopCommunity.B.Cone.8.Total': 0.3333333333333333,
#  'teleopCommunity.B.Cube.0.Total': 0.5,
#  'teleopCommunity.B.Cube.1.Total': 0.4166666666666667,
#  'teleopCommunity.B.Cube.2.Total': 0.3333333333333333,
#  'teleopCommunity.B.Cube.3.Total': 0.16666666666666666,
#  'teleopCommunity.B.Cube.4.Total': 0.3333333333333333,
#  'teleopCommunity.B.Cube.5.Total': 0.3333333333333333,
#  'teleopCommunity.B.Cube.6.Total': 0.4166666666666667,
#  'teleopCommunity.B.Cube.7.Total': 0.4166666666666667,
#  'teleopCommunity.B.Cube.8.Total': 0.4166666666666667,
#  'teleopCommunity.M.Cone.0.Total': 0.16666666666666666,
#  'teleopCommunity.M.Cone.1.Total': 0.0,
#  'teleopCommunity.M.Cone.2.Total': 0.25,
#  'teleopCommunity.M.Cone.3.Total': 0.08333333333333333,
#  'teleopCommunity.M.Cone.4.Total': 0.0,
#  'teleopCommunity.M.Cone.5.Total': 0.08333333333333333,
#  'teleopCommunity.M.Cone.6.Total': 0.16666666666666666,
#  'teleopCommunity.M.Cone.7.Total': 0.0,
#  'teleopCommunity.M.Cone.8.Total': 0.25,
#  'teleopCommunity.M.Cube.0.Total': 0.0,
#  'teleopCommunity.M.Cube.1.Total': 0.16666666666666666,
#  'teleopCommunity.M.Cube.2.Total': 0.0,
#  'teleopCommunity.M.Cube.3.Total': 0.0,
#  'teleopCommunity.M.Cube.4.Total': 0.08333333333333333,
#  'teleopCommunity.M.Cube.5.Total': 0.0,
#  'teleopCommunity.M.Cube.6.Total': 0.0,
#  'teleopCommunity.M.Cube.7.Total': 0.4166666666666667,
#  'teleopCommunity.M.Cube.8.Total': 0.0,
#  'teleopCommunity.T.Cone.0.Total': 0.8333333333333334,
#  'teleopCommunity.T.Cone.1.Total': 0.0,
#  'teleopCommunity.T.Cone.2.Total': 0.8333333333333334,
#  'teleopCommunity.T.Cone.3.Total': 0.16666666666666666,
#  'teleopCommunity.T.Cone.4.Total': 0.0,
#  'teleopCommunity.T.Cone.5.Total': 0.25,
#  'teleopCommunity.T.Cone.6.Total': 0.8333333333333334,
#  'teleopCommunity.T.Cone.7.Total': 0.0,
#  'teleopCommunity.T.Cone.8.Total': 0.8333333333333334,
#  'teleopCommunity.T.Cube.0.Total': 0.0,
#  'teleopCommunity.T.Cube.1.Total': 0.8333333333333334,
#  'teleopCommunity.T.Cube.2.Total': 0.0,
#  'teleopCommunity.T.Cube.3.Total': 0.0,
#  'teleopCommunity.T.Cube.4.Total': 0.08333333333333333,
#  'teleopCommunity.T.Cube.5.Total': 0.0,
#  'teleopCommunity.T.Cube.6.Total': 0.0,
#  'teleopCommunity.T.Cube.7.Total': 0.9166666666666666,
#  'teleopCommunity.T.Cube.8.Total': 0.0,
#  'teleopGamePieceCountTotal': 12.166666666666666,
#  'teleopGamePiecePointsTotal': 31.583333333333332,
#  'teleopPointsTotal': 51.916666666666664,
#  'totalChargeStationPointsTotal': 30.166666666666668,
#  'totalPointsTotal': 105.16666666666667,
#  'mobilityRobot1YesTotal': 0.6666666666666666,
#  'mobilityRobot1NoTotal': 0.3333333333333333,
#  'endGameChargeStationRobot1NoneTotal': 0.25,
#  'autoChargeStationRobot1NoneTotal': 0.5833333333333334,
#  'endGameChargeStationRobot1DockedTotal': 0.5,
#  'autoChargeStationRobot1DockedTotal': 0.4166666666666667,
#  'endGameChargeStationRobot1ParkTotal': 0.25,
#  'mobilityRobot2YesTotal': 0.5,
#  'mobilityRobot2NoTotal': 0.5,
#  'endGameChargeStationRobot2NoneTotal': 0.16666666666666666,
#  'autoChargeStationRobot2NoneTotal': 0.6666666666666666,
#  'endGameChargeStationRobot2DockedTotal': 0.75,
#  'autoChargeStationRobot2DockedTotal': 0.3333333333333333,
#  'endGameChargeStationRobot2ParkTotal': 0.08333333333333333,
#  'mobilityRobot3YesTotal': 0.6666666666666666,
#  'mobilityRobot3NoTotal': 0.3333333333333333,
#  'endGameChargeStationRobot3NoneTotal': 0.08333333333333333,
#  'autoChargeStationRobot3NoneTotal': 0.8333333333333334,
#  'endGameChargeStationRobot3DockedTotal': 0.6666666666666666,
#  'autoChargeStationRobot3DockedTotal': 0.16666666666666666,
#  'endGameChargeStationRobot3ParkTotal': 0.25,
#  'endGameBridgeStateLevelTotal': 1.0,
#  'autoBridgeStateLevelTotal': 1.0,
#  'endGameBridgeStateNotLevelTotal': 0.0,
#  'autoBridgeStateNotLevelTotal': 0.0}

# %% [markdown]
# Now we have statistics for every team.  We can use this to generate features for every match.

# %%
# featurizeAlliances builds a feature vector for each alliance, by summing over the stats for each robot in the alliance.

def featurizeAlliances(red, blue, label=0, comp_level='qm', event='none'):
    match_features = { 'red_missingCount':0, 'blue_missingCount': 0 }
    count=0    
    allKeys = set()
    for t in red:
        if t not in teamAggregates:
            match_features['red_missingCount']+=1
            continue
        for k in teamAggregates[t]:
            key = 'red_'+k
            if key not in match_features:
                match_features[key]=0
            match_features[key]+=teamAggregates[t][k]
            allKeys.add(key)
        count+=1
    # compute the average
    for k in allKeys:
        match_features[k]/=count
    count=0
    allKeys=set()
    for t in blue:
        if t not in teamAggregates:
            match_features['blue_missingCount']+=1
            continue
        for k in teamAggregates[t]:
            key = 'blue_'+k
            if key not in match_features:
                match_features[key]=0
            match_features[key]+=teamAggregates[t][k]
            allKeys.add(key)
        count+=1
    # compute the average
    for k in allKeys:
        match_features[k]/=count
    match_features['event']= event
    match_features['comp_level']= comp_level
    match_features['label']= label #int(m.winning_alliance=='red')    
    return match_features

def featurizeMatch(m):
    return featurizeAlliances(
        m.alliances.red.team_keys, 
        m.alliances.blue.team_keys, 
        label=int(m.winning_alliance=='red'),
        event = m.event_key, comp_level=m.comp_level)

def invertMatch(f):
    f2={}
    for k in f:
        k2 = k.replace('red_','temp_').replace('blue_','red_').replace('temp_','blue_')
        f2[k2]=f[k]
    f2['label']=1-f['label']
    return f2

features = []

for m in data:
    f = featurizeMatch(m)
    features.append(f)
    # Optionally invert the red/blue alliances and add this match as well, since it should be symmetric
    features.append(invertMatch(f))
    
features[0]
# Out:
# {'red_missingCount': 0,
#  'blue_missingCount': 0,
#  'red_totalMatches': 12.0,
#  'red_winCount': 0.5833333333333334,
#  'red_activationBonusAchievedTotal': 0.7222222222222222,
#  'red_adjustPointsTotal': 0.0,
#  'red_autoChargeStationPointsTotal': 9.0,
#  'red_autoCommunity.B.Cone.0.Total': 0.05555555555555555,
#  'red_autoCommunity.B.Cone.1.Total': 0.0,
#  'red_autoCommunity.B.Cone.2.Total': 0.0,
#  'red_autoCommunity.B.Cone.3.Total': 0.0,
#  'red_autoCommunity.B.Cone.4.Total': 0.027777777777777776,
#  'red_autoCommunity.B.Cone.5.Total': 0.08333333333333333,
#  'red_autoCommunity.B.Cone.6.Total': 0.027777777777777776,
#  'red_autoCommunity.B.Cone.7.Total': 0.05555555555555555,
#  'red_autoCommunity.B.Cone.8.Total': 0.027777777777777776,
#  'red_autoCommunity.B.Cube.0.Total': 0.027777777777777776,
#  'red_autoCommunity.B.Cube.1.Total': 0.0,
#  'red_autoCommunity.B.Cube.2.Total': 0.0,
#  'red_autoCommunity.B.Cube.3.Total': 0.0,
#  'red_autoCommunity.B.Cube.4.Total': 0.05555555555555555,
#  'red_autoCommunity.B.Cube.5.Total': 0.0,
#  'red_autoCommunity.B.Cube.6.Total': 0.0,
#  'red_autoCommunity.B.Cube.7.Total': 0.027777777777777776,
#  'red_autoCommunity.B.Cube.8.Total': 0.0,
#  'red_autoCommunity.M.Cone.0.Total': 0.0,
#  'red_autoCommunity.M.Cone.1.Total': 0.0,
#  'red_autoCommunity.M.Cone.2.Total': 0.0,
#  'red_autoCommunity.M.Cone.3.Total': 0.08333333333333333,
#  'red_autoCommunity.M.Cone.4.Total': 0.0,
#  'red_autoCommunity.M.Cone.5.Total': 0.0,
#  'red_autoCommunity.M.Cone.6.Total': 0.0,
#  'red_autoCommunity.M.Cone.7.Total': 0.0,
#  'red_autoCommunity.M.Cone.8.Total': 0.0,
#  'red_autoCommunity.M.Cube.0.Total': 0.0,
#  'red_autoCommunity.M.Cube.1.Total': 0.08333333333333333,
#  'red_autoCommunity.M.Cube.2.Total': 0.0,
#  'red_autoCommunity.M.Cube.3.Total': 0.0,
#  'red_autoCommunity.M.Cube.4.Total': 0.0,
#  'red_autoCommunity.M.Cube.5.Total': 0.0,
#  'red_autoCommunity.M.Cube.6.Total': 0.0,
#  'red_autoCommunity.M.Cube.7.Total': 0.027777777777777776,
#  'red_autoCommunity.M.Cube.8.Total': 0.0,
#  'red_autoCommunity.T.Cone.0.Total': 0.2777777777777778,
#  'red_autoCommunity.T.Cone.1.Total': 0.0,
#  'red_autoCommunity.T.Cone.2.Total': 0.0,
#  'red_autoCommunity.T.Cone.3.Total': 0.027777777777777776,
#  'red_autoCommunity.T.Cone.4.Total': 0.0,
#  'red_autoCommunity.T.Cone.5.Total': 0.05555555555555555,
#  'red_autoCommunity.T.Cone.6.Total': 0.027777777777777776,
#  'red_autoCommunity.T.Cone.7.Total': 0.0,
#  'red_autoCommunity.T.Cone.8.Total': 0.36111111111111116,
#  'red_autoCommunity.T.Cube.0.Total': 0.0,
#  'red_autoCommunity.T.Cube.1.Total': 0.25,
#  'red_autoCommunity.T.Cube.2.Total': 0.0,
#  'red_autoCommunity.T.Cube.3.Total': 0.0,
#  'red_autoCommunity.T.Cube.4.Total': 0.3333333333333333,
#  'red_autoCommunity.T.Cube.5.Total': 0.0,
#  'red_autoCommunity.T.Cube.6.Total': 0.0,
#  'red_autoCommunity.T.Cube.7.Total': 0.16666666666666666,
#  'red_autoCommunity.T.Cube.8.Total': 0.0,
#  'red_autoDockedTotal': 0.75,
#  'red_autoGamePieceCountTotal': 2.0833333333333335,
#  'red_autoGamePiecePointsTotal': 10.777777777777777,
#  'red_autoMobilityPointsTotal': 4.333333333333333,
#  'red_autoPointsTotal': 24.111111111111114,
#  'red_coopGamePieceCountTotal': 3.25,
#  'red_coopertitionCriteriaMetTotal': 0.7222222222222222,
#  'red_endGameChargeStationPointsTotal': 21.0,
#  'red_endGameParkPointsTotal': 1.0,
#  'red_foulCountTotal': 1.0833333333333333,
#  'red_foulPointsTotal': 4.777777777777778,
#  'red_linkPointsTotal': 12.361111111111112,
#  'red_rpTotal': 2.0833333333333335,
#  'red_sustainabilityBonusAchievedTotal': 0.19444444444444445,
#  'red_techFoulCountTotal': 0.08333333333333333,
#  'red_teleopCommunity.B.Cone.0.Total': 0.13888888888888887,
#  'red_teleopCommunity.B.Cone.1.Total': 0.08333333333333333,
#  'red_teleopCommunity.B.Cone.2.Total': 0.16666666666666666,
#  'red_teleopCommunity.B.Cone.3.Total': 0.1111111111111111,
#  'red_teleopCommunity.B.Cone.4.Total': 0.05555555555555555,
#  'red_teleopCommunity.B.Cone.5.Total': 0.19444444444444445,
#  'red_teleopCommunity.B.Cone.6.Total': 0.13888888888888887,
#  'red_teleopCommunity.B.Cone.7.Total': 0.1111111111111111,
#  'red_teleopCommunity.B.Cone.8.Total': 0.2222222222222222,
#  'red_teleopCommunity.B.Cube.0.Total': 0.4444444444444444,
#  'red_teleopCommunity.B.Cube.1.Total': 0.4166666666666667,
#  'red_teleopCommunity.B.Cube.2.Total': 0.3333333333333333,
#  'red_teleopCommunity.B.Cube.3.Total': 0.47222222222222227,
#  'red_teleopCommunity.B.Cube.4.Total': 0.6111111111111112,
#  'red_teleopCommunity.B.Cube.5.Total': 0.4444444444444444,
#  'red_teleopCommunity.B.Cube.6.Total': 0.36111111111111116,
#  'red_teleopCommunity.B.Cube.7.Total': 0.5277777777777778,
#  'red_teleopCommunity.B.Cube.8.Total': 0.5277777777777778,
#  'red_teleopCommunity.M.Cone.0.Total': 0.1111111111111111,
#  'red_teleopCommunity.M.Cone.1.Total': 0.0,
#  'red_teleopCommunity.M.Cone.2.Total': 0.16666666666666666,
#  'red_teleopCommunity.M.Cone.3.Total': 0.13888888888888887,
#  'red_teleopCommunity.M.Cone.4.Total': 0.0,
#  'red_teleopCommunity.M.Cone.5.Total': 0.1111111111111111,
#  'red_teleopCommunity.M.Cone.6.Total': 0.1111111111111111,
#  'red_teleopCommunity.M.Cone.7.Total': 0.0,
#  'red_teleopCommunity.M.Cone.8.Total': 0.13888888888888887,
#  'red_teleopCommunity.M.Cube.0.Total': 0.0,
#  'red_teleopCommunity.M.Cube.1.Total': 0.3333333333333333,
#  'red_teleopCommunity.M.Cube.2.Total': 0.0,
#  'red_teleopCommunity.M.Cube.3.Total': 0.0,
#  'red_teleopCommunity.M.Cube.4.Total': 0.25,
#  'red_teleopCommunity.M.Cube.5.Total': 0.0,
#  'red_teleopCommunity.M.Cube.6.Total': 0.0,
#  'red_teleopCommunity.M.Cube.7.Total': 0.47222222222222227,
#  'red_teleopCommunity.M.Cube.8.Total': 0.0,
#  'red_teleopCommunity.T.Cone.0.Total': 0.4444444444444445,
#  'red_teleopCommunity.T.Cone.1.Total': 0.0,
#  'red_teleopCommunity.T.Cone.2.Total': 0.47222222222222227,
#  'red_teleopCommunity.T.Cone.3.Total': 0.25,
#  'red_teleopCommunity.T.Cone.4.Total': 0.0,
#  'red_teleopCommunity.T.Cone.5.Total': 0.13888888888888887,
#  'red_teleopCommunity.T.Cone.6.Total': 0.47222222222222227,
#  'red_teleopCommunity.T.Cone.7.Total': 0.0,
#  'red_teleopCommunity.T.Cone.8.Total': 0.47222222222222227,
#  'red_teleopCommunity.T.Cube.0.Total': 0.0,
#  'red_teleopCommunity.T.Cube.1.Total': 0.6944444444444445,
#  'red_teleopCommunity.T.Cube.2.Total': 0.0,
#  'red_teleopCommunity.T.Cube.3.Total': 0.0,
#  'red_teleopCommunity.T.Cube.4.Total': 0.47222222222222227,
#  'red_teleopCommunity.T.Cube.5.Total': 0.0,
#  'red_teleopCommunity.T.Cube.6.Total': 0.0,
#  'red_teleopCommunity.T.Cube.7.Total': 0.6944444444444443,
#  'red_teleopCommunity.T.Cube.8.Total': 0.0,
#  'red_teleopGamePieceCountTotal': 11.305555555555555,
#  'red_teleopGamePiecePointsTotal': 28.055555555555557,
#  'red_teleopPointsTotal': 50.05555555555555,
#  'red_totalChargeStationPointsTotal': 30.0,
#  'red_totalPointsTotal': 91.30555555555556,
#  'red_mobilityRobot1YesTotal': 0.4444444444444444,
#  'red_mobilityRobot1NoTotal': 0.5555555555555555,
#  'red_endGameChargeStationRobot1NoneTotal': 0.16666666666666666,
#  'red_autoChargeStationRobot1NoneTotal': 0.7222222222222222,
#  'red_endGameChargeStationRobot1DockedTotal': 0.638888888888889,
#  'red_autoChargeStationRobot1DockedTotal': 0.2777777777777778,
#  'red_endGameChargeStationRobot1ParkTotal': 0.19444444444444442,
#  'red_mobilityRobot2YesTotal': 0.4444444444444444,
#  'red_mobilityRobot2NoTotal': 0.5555555555555555,
#  'red_endGameChargeStationRobot2NoneTotal': 0.13888888888888887,
#  'red_autoChargeStationRobot2NoneTotal': 0.8055555555555555,
#  'red_endGameChargeStationRobot2DockedTotal': 0.75,
#  'red_autoChargeStationRobot2DockedTotal': 0.19444444444444442,
#  'red_endGameChargeStationRobot2ParkTotal': 0.1111111111111111,
#  'red_mobilityRobot3YesTotal': 0.5555555555555556,
#  'red_mobilityRobot3NoTotal': 0.4444444444444445,
#  'red_endGameChargeStationRobot3NoneTotal': 0.08333333333333333,
#  'red_autoChargeStationRobot3NoneTotal': 0.7222222222222222,
#  'red_endGameChargeStationRobot3DockedTotal': 0.7222222222222222,
#  'red_autoChargeStationRobot3DockedTotal': 0.27777777777777773,
#  'red_endGameChargeStationRobot3ParkTotal': 0.19444444444444442,
#  'red_endGameBridgeStateLevelTotal': 0.9722222222222222,
#  'red_autoBridgeStateLevelTotal': 0.9166666666666666,
#  'red_endGameBridgeStateNotLevelTotal': 0.027777777777777776,
#  'red_autoBridgeStateNotLevelTotal': 0.08333333333333333,
#  'blue_totalMatches': 12.0,
#  'blue_winCount': 0.7222222222222222,
#  'blue_activationBonusAchievedTotal': 0.7777777777777777,
#  'blue_adjustPointsTotal': 0.0,
#  'blue_autoChargeStationPointsTotal': 10.555555555555555,
#  'blue_autoCommunity.B.Cone.0.Total': 0.08333333333333333,
#  'blue_autoCommunity.B.Cone.1.Total': 0.0,
#  'blue_autoCommunity.B.Cone.2.Total': 0.0,
#  'blue_autoCommunity.B.Cone.3.Total': 0.08333333333333333,
#  'blue_autoCommunity.B.Cone.4.Total': 0.027777777777777776,
#  'blue_autoCommunity.B.Cone.5.Total': 0.027777777777777776,
#  'blue_autoCommunity.B.Cone.6.Total': 0.027777777777777776,
#  'blue_autoCommunity.B.Cone.7.Total': 0.027777777777777776,
#  'blue_autoCommunity.B.Cone.8.Total': 0.1111111111111111,
#  'blue_autoCommunity.B.Cube.0.Total': 0.027777777777777776,
#  'blue_autoCommunity.B.Cube.1.Total': 0.05555555555555555,
#  'blue_autoCommunity.B.Cube.2.Total': 0.027777777777777776,
#  'blue_autoCommunity.B.Cube.3.Total': 0.0,
#  'blue_autoCommunity.B.Cube.4.Total': 0.027777777777777776,
#  'blue_autoCommunity.B.Cube.5.Total': 0.0,
#  'blue_autoCommunity.B.Cube.6.Total': 0.05555555555555555,
#  'blue_autoCommunity.B.Cube.7.Total': 0.027777777777777776,
#  'blue_autoCommunity.B.Cube.8.Total': 0.0,
#  'blue_autoCommunity.M.Cone.0.Total': 0.0,
#  'blue_autoCommunity.M.Cone.1.Total': 0.0,
#  'blue_autoCommunity.M.Cone.2.Total': 0.0,
#  'blue_autoCommunity.M.Cone.3.Total': 0.2777777777777778,
#  'blue_autoCommunity.M.Cone.4.Total': 0.0,
#  'blue_autoCommunity.M.Cone.5.Total': 0.0,
#  'blue_autoCommunity.M.Cone.6.Total': 0.0,
#  'blue_autoCommunity.M.Cone.7.Total': 0.0,
#  'blue_autoCommunity.M.Cone.8.Total': 0.027777777777777776,
#  'blue_autoCommunity.M.Cube.0.Total': 0.0,
#  'blue_autoCommunity.M.Cube.1.Total': 0.08333333333333333,
#  'blue_autoCommunity.M.Cube.2.Total': 0.0,
#  'blue_autoCommunity.M.Cube.3.Total': 0.0,
#  'blue_autoCommunity.M.Cube.4.Total': 0.0,
#  'blue_autoCommunity.M.Cube.5.Total': 0.0,
#  'blue_autoCommunity.M.Cube.6.Total': 0.0,
#  'blue_autoCommunity.M.Cube.7.Total': 0.1111111111111111,
#  'blue_autoCommunity.M.Cube.8.Total': 0.0,
#  'blue_autoCommunity.T.Cone.0.Total': 0.3333333333333333,
#  'blue_autoCommunity.T.Cone.1.Total': 0.0,
#  'blue_autoCommunity.T.Cone.2.Total': 0.0,
#  'blue_autoCommunity.T.Cone.3.Total': 0.0,
#  'blue_autoCommunity.T.Cone.4.Total': 0.0,
#  'blue_autoCommunity.T.Cone.5.Total': 0.08333333333333333,
#  'blue_autoCommunity.T.Cone.6.Total': 0.0,
#  'blue_autoCommunity.T.Cone.7.Total': 0.0,
#  'blue_autoCommunity.T.Cone.8.Total': 0.3611111111111111,
#  'blue_autoCommunity.T.Cube.0.Total': 0.0,
#  'blue_autoCommunity.T.Cube.1.Total': 0.13888888888888887,
#  'blue_autoCommunity.T.Cube.2.Total': 0.0,
#  'blue_autoCommunity.T.Cube.3.Total': 0.0,
#  'blue_autoCommunity.T.Cube.4.Total': 0.1111111111111111,
#  'blue_autoCommunity.T.Cube.5.Total': 0.0,
#  'blue_autoCommunity.T.Cube.6.Total': 0.0,
#  'blue_autoCommunity.T.Cube.7.Total': 0.16666666666666666,
#  'blue_autoCommunity.T.Cube.8.Total': 0.0,
#  'blue_autoDockedTotal': 0.9166666666666666,
#  'blue_autoGamePieceCountTotal': 2.305555555555556,
#  'blue_autoGamePiecePointsTotal': 11.0,
#  'blue_autoMobilityPointsTotal': 4.416666666666667,
#  'blue_autoPointsTotal': 25.972222222222225,
#  'blue_coopGamePieceCountTotal': 3.75,
#  'blue_coopertitionCriteriaMetTotal': 0.7777777777777778,
#  'blue_endGameChargeStationPointsTotal': 20.22222222222222,
#  'blue_endGameParkPointsTotal': 1.0,
#  'blue_foulCountTotal': 0.9444444444444445,
#  'blue_foulPointsTotal': 3.9444444444444446,
#  'blue_linkPointsTotal': 13.333333333333334,
#  'blue_rpTotal': 2.388888888888889,
#  'blue_sustainabilityBonusAchievedTotal': 0.16666666666666666,
#  'blue_techFoulCountTotal': 0.027777777777777776,
#  'blue_teleopCommunity.B.Cone.0.Total': 0.16666666666666666,
#  'blue_teleopCommunity.B.Cone.1.Total': 0.08333333333333333,
#  'blue_teleopCommunity.B.Cone.2.Total': 0.1111111111111111,
#  'blue_teleopCommunity.B.Cone.3.Total': 0.13888888888888887,
#  'blue_teleopCommunity.B.Cone.4.Total': 0.13888888888888887,
#  'blue_teleopCommunity.B.Cone.5.Total': 0.16666666666666666,
#  'blue_teleopCommunity.B.Cone.6.Total': 0.2222222222222222,
#  'blue_teleopCommunity.B.Cone.7.Total': 0.16666666666666666,
#  'blue_teleopCommunity.B.Cone.8.Total': 0.2222222222222222,
#  'blue_teleopCommunity.B.Cube.0.Total': 0.3055555555555555,
#  'blue_teleopCommunity.B.Cube.1.Total': 0.38888888888888884,
#  'blue_teleopCommunity.B.Cube.2.Total': 0.25,
#  'blue_teleopCommunity.B.Cube.3.Total': 0.2222222222222222,
#  'blue_teleopCommunity.B.Cube.4.Total': 0.3611111111111111,
#  'blue_teleopCommunity.B.Cube.5.Total': 0.19444444444444442,
#  'blue_teleopCommunity.B.Cube.6.Total': 0.25,
#  'blue_teleopCommunity.B.Cube.7.Total': 0.25,
#  'blue_teleopCommunity.B.Cube.8.Total': 0.3333333333333333,
#  'blue_teleopCommunity.M.Cone.0.Total': 0.16666666666666666,
#  'blue_teleopCommunity.M.Cone.1.Total': 0.0,
#  'blue_teleopCommunity.M.Cone.2.Total': 0.2777777777777778,
#  'blue_teleopCommunity.M.Cone.3.Total': 0.4166666666666667,
#  'blue_teleopCommunity.M.Cone.4.Total': 0.0,
#  'blue_teleopCommunity.M.Cone.5.Total': 0.4444444444444445,
#  'blue_teleopCommunity.M.Cone.6.Total': 0.27777777777777773,
#  'blue_teleopCommunity.M.Cone.7.Total': 0.0,
#  'blue_teleopCommunity.M.Cone.8.Total': 0.27777777777777773,
#  'blue_teleopCommunity.M.Cube.0.Total': 0.0,
#  'blue_teleopCommunity.M.Cube.1.Total': 0.4166666666666667,
#  'blue_teleopCommunity.M.Cube.2.Total': 0.0,
#  'blue_teleopCommunity.M.Cube.3.Total': 0.0,
#  'blue_teleopCommunity.M.Cube.4.Total': 0.5277777777777778,
#  'blue_teleopCommunity.M.Cube.5.Total': 0.0,
#  'blue_teleopCommunity.M.Cube.6.Total': 0.0,
#  'blue_teleopCommunity.M.Cube.7.Total': 0.5555555555555555,
#  'blue_teleopCommunity.M.Cube.8.Total': 0.0,
#  'blue_teleopCommunity.T.Cone.0.Total': 0.5277777777777778,
#  'blue_teleopCommunity.T.Cone.1.Total': 0.0,
#  'blue_teleopCommunity.T.Cone.2.Total': 0.611111111111111,
#  'blue_teleopCommunity.T.Cone.3.Total': 0.3888888888888889,
#  'blue_teleopCommunity.T.Cone.4.Total': 0.0,
#  'blue_teleopCommunity.T.Cone.5.Total': 0.3333333333333333,
#  'blue_teleopCommunity.T.Cone.6.Total': 0.5,
#  'blue_teleopCommunity.T.Cone.7.Total': 0.0,
#  'blue_teleopCommunity.T.Cone.8.Total': 0.5833333333333334,
#  'blue_teleopCommunity.T.Cube.0.Total': 0.0,
#  'blue_teleopCommunity.T.Cube.1.Total': 0.6666666666666666,
#  'blue_teleopCommunity.T.Cube.2.Total': 0.0,
#  'blue_teleopCommunity.T.Cube.3.Total': 0.0,
#  'blue_teleopCommunity.T.Cube.4.Total': 0.4166666666666667,
#  'blue_teleopCommunity.T.Cube.5.Total': 0.0,
#  'blue_teleopCommunity.T.Cube.6.Total': 0.0,
#  'blue_teleopCommunity.T.Cube.7.Total': 0.5555555555555556,
#  'blue_teleopCommunity.T.Cube.8.Total': 0.0,
#  'blue_teleopGamePieceCountTotal': 11.916666666666666,
#  'blue_teleopGamePiecePointsTotal': 32.25,
#  'blue_teleopPointsTotal': 53.47222222222222,
#  'blue_totalChargeStationPointsTotal': 30.777777777777775,
#  'blue_totalPointsTotal': 96.72222222222223,
#  'blue_mobilityRobot1YesTotal': 0.4444444444444444,
#  'blue_mobilityRobot1NoTotal': 0.5555555555555555,
#  'blue_endGameChargeStationRobot1NoneTotal': 0.27777777777777773,
#  'blue_autoChargeStationRobot1NoneTotal': 0.7222222222222222,
#  'blue_endGameChargeStationRobot1DockedTotal': 0.5277777777777778,
#  'blue_autoChargeStationRobot1DockedTotal': 0.27777777777777773,
#  'blue_endGameChargeStationRobot1ParkTotal': 0.19444444444444442,
#  'blue_mobilityRobot2YesTotal': 0.4444444444444445,
#  'blue_mobilityRobot2NoTotal': 0.5555555555555556,
#  'blue_endGameChargeStationRobot2NoneTotal': 0.1111111111111111,
#  'blue_autoChargeStationRobot2NoneTotal': 0.6388888888888888,
#  'blue_endGameChargeStationRobot2DockedTotal': 0.7222222222222222,
#  'blue_autoChargeStationRobot2DockedTotal': 0.3611111111111111,
#  'blue_endGameChargeStationRobot2ParkTotal': 0.16666666666666666,
#  'blue_mobilityRobot3YesTotal': 0.5833333333333334,
#  'blue_mobilityRobot3NoTotal': 0.4166666666666667,
#  'blue_endGameChargeStationRobot3NoneTotal': 0.05555555555555555,
#  'blue_autoChargeStationRobot3NoneTotal': 0.7222222222222223,
#  'blue_endGameChargeStationRobot3DockedTotal': 0.8055555555555555,
#  'blue_autoChargeStationRobot3DockedTotal': 0.2777777777777778,
#  'blue_endGameChargeStationRobot3ParkTotal': 0.13888888888888887,
#  'blue_endGameBridgeStateLevelTotal': 0.9444444444444443,
#  'blue_autoBridgeStateLevelTotal': 0.8888888888888888,
#  'blue_endGameBridgeStateNotLevelTotal': 0.05555555555555555,
#  'blue_autoBridgeStateNotLevelTotal': 0.1111111111111111,
#  'event': '2023arli',
#  'comp_level': 'f',
#  'label': 1}

# %%
from sklearn.feature_extraction import DictVectorizer
# create train and test sets
train = []
trainY = []
test = []
testY = []

for m in features:    
    if 'event' not in m:
        print(m)
    event = m['event']
    comp_level = m['comp_level']
    del m['event']
    del m['comp_level']
    
    label = m['label']
    del m['label']
    
    #if event == '2019pncmp':
    if comp_level!='qm':
        test.append(m)
        testY.append(label)
    else:
        train.append(m)
        trainY.append(label)
        
vectorizer = DictVectorizer()
trainX = vectorizer.fit_transform(train)
testX = vectorizer.transform(test)

print('{} training examples and {} test'.format(len(train),len(test)))
# Out:
# 3846 training examples and 884 test

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators=100, random_state=0, min_samples_split=3)  
classifier.fit(trainX,trainY)
forest_predictions= classifier.predict(testX)
forest_scores = classifier.predict_proba(testX)
import numpy as np
from sklearn.metrics import accuracy_score
#np.sum(np.abs(scores-Ytest))
print('accuracy: {}'.format(accuracy_score(testY, forest_predictions)))
#list(zip(forest_scores[:,1],testY))

# Save the model
model_fn = 'model_2023_forest.pkl'
with open(model_fn, 'wb') as outF:
    pickle.dump((vectorizer,classifier), outF)
# Out:
# accuracy: 0.7036199095022625

# %% [markdown]
# Let's look at the feature importances. They tell us how useful a specific feature is.

# %%
topN = 20
importances = classifier.feature_importances_
std = np.std([tree.feature_importances_ for tree in classifier.estimators_],
             axis=0)
indices = np.argsort(importances)[::-1][:topN]
names = vectorizer.feature_names_

# Print the feature ranking
print("Feature ranking:")

#for f in range(trainX.shape[1]):
#    print("%d. %s (%f)" % (f + 1, names[indices[f]], importances[indices[f]]))
colors = [names[f].split('_')[0] for f in indices]
labels = [names[f].replace('Count','').replace('Points','').replace('red','r').replace('blue','b') for f in indices]
# Plot the feature importances of the forest
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20, 10)
plt.figure()
plt.title("Feature importances")
#plt.bar(range(trainX.shape[1]), importances[indices],
plt.bar(range(len(indices)), importances[indices],
       color=colors, 
        #yerr=std[indices], 
        align="center")
plt.xticks(range(len(indices)), labels, rotation='vertical', fontsize='large')
    
plt.xlim([-1, len(indices)])
plt.subplots_adjust(bottom=0.5)
#plt.legend()
plt.show()
# Out:
# Feature ranking:

# %%
def percentile(dictionary, key):
    teams = [t for t in dictionary]
    values = [dictionary[t][key] for t in dictionary]
    ranks = sorted(range(len(values)), key=lambda x: values[x])
    return dict([(teams[ranks[i]], i*100/len(values)) for i in range(len(ranks))])    

raw = dict([(k, percentile(teamAggregates,k)) for k in teamAggregates['frc1153']])
#stats = dict([(k,percentile(teamAggregates,k)['frc1153']) for k in teamAggregates['frc1153']])

# %% [markdown]
# The next cell enables comparisons between two teams.

# %%
import matplotlib.pyplot as plt
import numpy as np

objects = [k for k in raw]
y_pos = np.arange(len(objects))
#performance = [[raw[k]['frc492'],raw[k]['frc2910']] for k in stats]
#performance
t1 = 'frc1153'
t2 = 'frc238'
plt.figure()
plt.bar(y_pos, [raw[k][t1] for k in raw], alpha=0.5, width=0.25)
plt.bar(y_pos+0.25, [raw[k][t2] for k in raw], alpha=0.5, width=0.25)
plt.xticks(y_pos, objects, rotation=90, fontsize='x-small')
plt.subplots_adjust(bottom=0.5)
plt.ylabel('Percentile')
plt.title('Stats summary')
plt.legend([t1,t2])

plt.show()

# %% [markdown]
# ## Let's also try logistic regression.

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state=0, solver='lbfgs', multi_class='multinomial', max_iter=10000)
classifier.fit(trainX,trainY)
lr_predictions= classifier.predict(testX)
accuracy_score(testY, lr_predictions)
# Out:
# 0.6843891402714932

# %%
importances = classifier.coef_[0]
#std = np.std([tree.feature_importances_ for tree in classifier.estimators_],
#             axis=0)
indices = np.argsort(importances)[::-1]
names = vectorizer.feature_names_

# Print the feature ranking
print("Feature ranking:")

#for f in range(trainX.shape[1]):
#    print("%d. %s (%f)" % (f + 1, names[indices[f]], importances[indices[f]]))
colors = [names[indices[f]].split('_')[0] for f in range(trainX.shape[1])]
labels = [names[indices[f]].replace('Count','').replace('Points','').replace('red','r').replace('blue','b') for f in range(trainX.shape[1])]
# Plot the feature importances of the forest
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20, 10)
plt.figure()
plt.title("Feature importances")
plt.bar(range(trainX.shape[1]), importances[indices],
       color=colors, 
        #yerr=std[indices], 
        align="center")
plt.xticks(range(trainX.shape[1]), labels, rotation='vertical', fontsize='x-small')
    
plt.xlim([-1, trainX.shape[1]])
plt.subplots_adjust(bottom=0.5)
#plt.legend()
plt.show()
# Out:
# Feature ranking:

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import RidgeClassifier
classifier = RidgeClassifier()
classifier.fit(trainX,trainY)
predictions= classifier.predict(testX)
accuracy_score(testY, predictions)
# Out:
# 0.670814479638009

# %% [markdown]
# So far our best score at predicting the districts is 0.704 using RandomForests.  Next time we can explore hyperparameter tuning and also predicting which alliances would have been the best ones for us to join.

# %% [markdown]
# Next steps: for a given event we want to decide how to prioritize alliance choices.  Suppose we have all the data to date, as well as all the qualifier data for the event. Who should we choose as partners?

# %%
# optimize alliances for frc492 at wasno:
import random
from tqdm import tqdm

event = '2023wasno'
teams = set([t for x in \
    [m.alliances.red.team_keys + m.alliances.blue.team_keys for m in matches['matches'][event]] \
        for t in x])

model_fn = 'model_2023_forest.pkl'
with open(model_fn, 'rb') as inF:
    vectorizer, model = pickle.load(inF)

target = 'frc492'
pairs = [(x,y) for x in teams if x!=target for y in teams if y!=target if x<y]
results = {}
features = []
alliances = []
for (x,y) in tqdm(pairs):
    red = [target, x, y]
    candidates = [x for x in teams if x not in red]
    trials = 100
    
    for m in range(trials):
        blue = random.sample(candidates, 3)
        f = featurizeAlliances(red, blue)
        features.append(f)
        alliances.append([red,blue])

scores = model.predict_proba(vectorizer.transform(features))
results = {}
for ((_,x,y),_), score in zip(alliances, scores): 
    if (x,y) not in results:
        results[(x,y)] = 0
    results[(x,y)] += score[0]    


for r in list(sorted(results, key=lambda x: results[x], reverse=True))[:100]:
    print(r, results[r])
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 561/561 [00:36<00:00, 15.29it/s]
# ('frc2097', 'frc4682') 91.55333333333334
# ('frc2097', 'frc5941') 91.55166666666668
# ('frc2097', 'frc8248') 91.21833333333332
# ('frc2097', 'frc2903') 91.20633333333333
# ('frc2097', 'frc3681') 91.16666666666664
# ('frc2097', 'frc3268') 90.93666666666667
# ('frc3268', 'frc6350') 90.85566666666666
# ('frc2097', 'frc3049') 90.664
# ('frc2097', 'frc6350') 90.40000000000003
# ('frc1778', 'frc2097') 90.37999999999997
# ('frc2097', 'frc4512') 90.34333333333333
# ('frc4512', 'frc6350') 90.22500000000005
# ('frc2097', 'frc5588') 90.19494736842107
# ('frc5588', 'frc6350') 90.01833333333333
# ('frc5588', 'frc949') 89.71750000000002
# ('frc2928', 'frc6350') 89.57999999999996
# ('frc6350', 'frc9036') 89.555
# ('frc2097', 'frc949') 89.39249999999998
# ('frc2097', 'frc4089') 89.20083333333335
# ('frc6350', 'frc949') 88.91666666666666
# ('frc2903', 'frc949') 88.82916666666661
# ('frc3268', 'frc5588') 88.72249999999995
# ('frc3268', 'frc3681') 88.53283333333331
# ('frc3681', 'frc949') 88.13083333333334
# ('frc2903', 'frc6350') 87.94833333333334
# ('frc2097', 'frc9036') 87.74627705627705
# ('frc3268', 'frc8248') 87.69999999999997
# ('frc3681', 'frc6350') 87.59833333333333
# ('frc3681', 'frc5588') 87.26200000000003
# ('frc2903', 'frc3268') 87.11833333333333
# ('frc6350', 'frc8248') 87.01333333333338
# ('frc2903', 'frc3681') 86.98083333333332
# ('frc4682', 'frc6350') 86.8725
# ('frc1778', 'frc2903') 86.865
# ('frc1899', 'frc2097') 86.85416666666667
# ('frc2097', 'frc4980') 86.80333333333333
# ('frc5941', 'frc6350') 86.78249999999997
# ('frc2097', 'frc2928') 86.76233333333333
# ('frc3826', 'frc6350') 86.60666666666667
# ('frc2980', 'frc6350') 86.54583333333332
# ('frc8248', 'frc949') 86.32749999999999
# ('frc2097', 'frc2980') 85.31966666666663
# ('frc1778', 'frc949') 85.19999999999999
# ('frc2097', 'frc3826') 84.8566666666667
# ('frc1778', 'frc3681') 84.82416666666668
# ('frc2928', 'frc3268') 84.71499999999999
# ('frc4980', 'frc6350') 84.66916666666674
# ('frc5588', 'frc8248') 84.57199999999996
# ('frc1778', 'frc6350') 84.56666666666666
# ('frc2903', 'frc8248') 84.55916666666663
# ('frc1778', 'frc5588') 84.52065261044177
# ('frc1778', 'frc4512') 84.36500000000002
# ('frc3681', 'frc8248') 84.18228403755867
# ('frc4512', 'frc949') 83.91372413793104
# ('frc3049', 'frc6350') 83.91166666666666
# ('frc3681', 'frc4089') 83.84383333333338
# ('frc3268', 'frc5941') 83.83333333333331
# ('frc3268', 'frc4512') 83.60733333333329
# ('frc2928', 'frc5588') 83.59500000000003
# ('frc4089', 'frc949') 83.34499999999997
# ('frc1778', 'frc8248') 83.26083333333334
# ('frc3268', 'frc949') 83.18383333333333
# ('frc5941', 'frc949') 82.99400000000001
# ('frc3049', 'frc3681') 82.92666666666668
# ('frc9036', 'frc949') 82.742724137931
# ('frc3049', 'frc8248') 82.66166666666666
# ('frc3268', 'frc4089') 82.35500000000003
# ('frc1778', 'frc3268') 82.32005747126432
# ('frc3049', 'frc3268') 82.29333333333335
# ('frc2928', 'frc3681') 82.10333333333328
# ('frc1899', 'frc3268') 82.04749999999999
# ('frc4089', 'frc8248') 81.64383333333335
# ('frc3681', 'frc9036') 81.5173333333333
# ('frc5588', 'frc5941') 81.03898594377507
# ('frc3268', 'frc3826') 80.91583333333325
# ('frc2980', 'frc3268') 80.85916666666665
# ('frc4980', 'frc5588') 80.75999999999999
# ('frc1899', 'frc6350') 80.73083333333331
# ('frc3049', 'frc949') 80.59749999999998
# ('frc3049', 'frc5588') 80.56333333333336
# ('frc5588', 'frc9036') 80.2548333333333
# ('frc3681', 'frc4682') 80.21666666666668
# ('frc3268', 'frc4682') 80.15083333333331
# ('frc2976', 'frc6350') 80.14666666666663
# ('frc3681', 'frc5941') 80.07666666666663
# ('frc3681', 'frc4512') 79.96105128205129
# ('frc2903', 'frc4980') 79.91916666666668
# ('frc4682', 'frc8248') 79.91416666666667
# ('frc4682', 'frc949') 79.871
# ('frc2903', 'frc4512') 79.85866666666665
# ('frc2903', 'frc3049') 79.75816666666668
# ('frc2903', 'frc5588') 79.74666666666664
# ('frc2980', 'frc949') 79.74416666666666
# ('frc4089', 'frc6350') 79.68083333333331
# ('frc1778', 'frc2928') 79.5881666666667
# ('frc8248', 'frc9036') 79.52166666666668
# ('frc2928', 'frc949') 79.47522413793108
# ('frc4980', 'frc8248') 79.44499999999998
# ('frc1778', 'frc4682') 79.38916666666671
# ('frc4980', 'frc949') 79.35749999999999
